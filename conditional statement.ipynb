# %% [markdown]
# ## 1. Coditional Statements
#
# Conditional statements allow your program to execute specific blocks of code based on whether a condition is True or False.
#
# ### if Statement
#
# * Purpose: Executes a block of code only if a specified condition is true.
# * Syntax:
#     if condition:
#      _Code to executive if condition is true_
#      _This block MUST be indented_
#     _Code here runs regardless(it's outside the if block)
#
# * Example:
#     age = 20
#
#     if age >=18:
#         print("Your are elegible to vote.") # This line runs because 20 >=18 is true
#     print("Program continues...") # This line runs always
#
# if-else statement
#
# * Purpose: Execute one block of code if a condition is True and a different block if the condition is False. It provides an alternative path.
#
# * Syntax:
#     if condition:
#         # Code to execute if condition is true
#         # Indented block
#     else:
#         # Code to execute if condition is false
#         # Indented block

# %%
num = 10

if num >0:
    print("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative number")
# Out:
# Positive number

# %%
num = 7

if num % 2 ==0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Odd number

# %%
marks = 85

if marks >= 90:
    print("Grade A")
elif marks >=75 and marks<90:
    print("Grade B")
elif marks >=50 and marks <75:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade B

# %%
# Login check

username = "admin"
password = "1234"

if username == "admin" and password == "1234":
    print("login successful")
elif username == "admin":
    print("Wrong password")
else:
    print("User not found")
# Out:
# login successful

# %%
# Practice Questions
# 1. Positive, Negative, or Zero.. write a program: take a number and print is positive or negative or zero

number = int(input("Enter the number:"))

if number > 0:
    print("This number is Positive")
elif number < 0:
    print("This number is negative")
else:
    print("The number is Zero")
# Out:
# This number is Positive

# %%
# Write a program: *Take a number and print the nmber is Even or odd
try:
    number = int(input("Enter the number:"))

    if number % 2 == 0:
        print("Number is even")
    else:
        print("Number is odd")
except ValueError:
    print("Please enter a valid number")
# Out:
# Please enter a valid number

# %%
try:
    number = int(input("Enter the number:"))
    if number % 2 == 0:
        print("Number is even")
    else:
        print("Number is odd")
except ValueError:
    print("Please enter a valid number")
# Out:
# Please enter a valid number

# %%
try:
    marks = float(input("Enter the obtained marks:"))

    if marks >=90:
        print("Grade A")
    elif marks >=75 and marks <=89:
        print("Grade B")
    elif marks >=50 and marks <=74:
        print("Grade C")
    else:
        print("Fail")
except ValueError:
    print("Enter valid marks")
# Out:
# Grade A

# %%
try:
    marks = float(input("Enter the obtained marks: "))

    if marks < 0 or marks >100:
        print("Marks should be between 0 and 100")
    elif marks >=90:
        print("Grade A")
    elif marks >=75:
        print("Grade B")
    elif marks >= 50:
        print("Grade C")
    else:
        print("Fail")
except ValueError:
    print("Enter valid marks")
# Out:
# Grade A

# %%
# Biggest of 3 numbers
try:
    a = float(input("Enter first number "))
    b = float(input("Enter second number "))
    c = float(input("Enter third number "))

    if a==b==c:
        print("All numbers are equal")
    elif a >= b and a >= c:
        print("Largest number is:", a)
    elif b >= a and b >= c:
        print("Largest number is:", b)
    else:
        print("Largest number is:", c)
except ValueError:
    print("Enter valid number")
# Out:
# All numbers are equal

# %%
try:
    a = float(input("Enter the first number"))
    b = float(input("Enter the second number"))
    c = float(input("Enter the third number"))

    if a == b == c:
        print("All numbers are equal")
    else:
        largest = max(a, b, c)
        print("Lasgest number is:", largest)
except ValueError:
    print("Enter valid number")
# Out:
# Lasgest number is: 33.0

# %%
# Discount calculator

a = float(input("Purchesed Amount: "))

if a >= 1000:
    discount1 = a - (a/100 * 20)
    print("Final Amount is ", discount1)
elif a >= 500:
    discount2 = a - (a/100 * 10)
    print("Fianl Amount is:", discount2)
else:
    print("No discount")
    print("Final amount is:", a)
# Out:
# No discount
# Final amount is: 499.0

# %%
try: 
    a = float(input("Purchased Amount: "))

    if a < 0:
        print("Amount can not be negative")
    else:
        print(f"The Purchased amount is: {a}")

        if a >= 1000:
            discount = 20
        elif a >= 500:
            discount = 10
        else:
            discount = 0
        final_amount = a-(a*discount/100)

        print(f"Discount applied: {discount}%")
        print(f"After discount amount is: {final_amount:.2f}")
except ValueError:
    print("Enter valid amount")
# Out:
# The Purchased amount is: 9827.0
# Discount applied: 20%
# After discount amount is: 7861.60
