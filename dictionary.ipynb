# %% [markdown]
# ## Mapping Type (dict)
# Explanation: Dictionaries (dict) store collections of key-value pairs. Keys must be unique and hashable (immutable types like strings, numbers, tuples containing only hashables). Values can be of any type and are accessed using their corresponding key. Dictionaries are mutable. As of Python 3.7+, dictionaries remember the insertion order of items.

# %% [markdown]
# #### Commom Operations & Method:
#
# ### a) Creation, Accessing ([], get()), Adding/updating
#
# Creating dictionaries, retrieving values using keys, and adding new key-value pairs or updating existing ones. [] raises KeyError if key is missing, get(key, default=none) returns none(oe a specified default) instead.

# %%
learning_paths = {
    "Data Science": ["Python", "Pandas", "ML"],
    "Data Engineering": ["ADF", "ADLS", "Databricks"],
}
student_ratings = {"Alice": 4.5, "Bob": 4.8}

# %%
print(f"1. Learning paths: {learning_paths}")
# Out:
# 1. Learning paths: {'Data Science': ['Python', 'Pandas', 'ML'], 'Data Engineering': ['ADF', 'ADLS', 'Databricks']}

# %%
ds_tools = learning_paths["Data Science"]
print(f"2. Data science tools: {ds_tools}")
# Out:
# 2. Data science tools: ['Python', 'Pandas', 'ML']

# %%
#Access a non existing key using [] (key error)

cloud_tools = learning_paths["Cloud Computing"]
print(f"Error accessing 'cloud computing' with []: {e}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 #Access a non existing key using [] (key error)
# ----> 3 cloud_tools = learning_paths["Cloud Computing"]
#       4 print(f"Error accessing 'cloud computing' with []: {e}")
#
# KeyError: 'Cloud Computing'

# %%
#access the tools for data engineering using get()

de_tools = learning_paths.get("Data Engineering")
print(f" Data Engineering tools: {de_tools}")
# Out:
#  Data Engineering tools: ['ADF', 'ADLS', 'Databricks']

# %%
# Access non-existing key using get() with default value

ml_tools_get = learning_paths.get("machine learning", [])
print(f"Machine leaning tools (get with default): {ml_tools_get}")
# Out:
# Machine leaning tools (get with default): []

# %%
# Add a new learning path (Azure devOps)
learning_paths["Azure DevOps"] = ["Python", " Pandas", "ML", "Visualization"]
print(f"Learning paths after adding ADO: {learning_paths}")
# Out:
# Learning paths after adding ADO: {'Data Science': ['Python', 'Pandas', 'ML'], 'Data Engineering': ['ADF', 'ADLS', 'Databricks'], 'Azure DevOps': ['Python', ' Pandas', 'ML', 'Visualization']}

# %%
# Update the tools for data Science

learning_paths["Data Science"] = ["Python", "Pandas", "ML", "visualization"]
print(f"Learing patha after updating data science: {learning_paths}")
# Out:
# Learing patha after updating data science: {'Data Science': ['Python', 'Pandas', 'ML', 'visualization'], 'Data Engineering': ['ADF', 'ADLS', 'Databricks'], 'Azure DevOps': ['Python', ' Pandas', 'ML', 'Visualization']}

# %%
# Add a new student rating

student_ratings["charlie"] = 4.9
print(student_ratings)
# Out:
# {'Alice': 4.5, 'Bob': 4.8, 'charlie': 4.9}

# %%
empty_dict = {}
my_dictionary = {1: "value", "value":1}

# %%
person = dict(name = "Alice", age = 25, city = "Mumbai")

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Mumbai'}

# %%
type(person)
# Out:
# dict

# %%
## from a list of tuple

pairs = [("name", "Somename"), ("age", 30), ("city", "mumbai")]
type(pairs)
# Out:
# list

# %%
person = dict(pairs)
person
# Out:
# {'name': 'Somename', 'age': 30, 'city': 'mumbai'}

# %%
type(person)
# Out:
# dict

# %%
## using fromkey() - same value for multiple keays

keys = ["name", "age", "city"]
default_value = dict.fromkeys(keys, "unknown")

# %%
default_value
# Out:
# {'name': 'unknown', 'age': 'unknown', 'city': 'unknown'}

# %%
type(default_value)
# Out:
# dict

# %%
## Accessing dictionary items

person = {'name': 'Alice', 'age' : 34, 'city': 'mumbai'}
person["name"]
# Out:
# 'Alice'

# %%
person["age"]
# Out:
# 34

# %%
#3 Using get() method (safer)

person
# Out:
# {'name': 'Alice', 'age': 34, 'city': 'mumbai'}

# %%
person.get("name")
# Out:
# 'Alice'

# %%
person.get("Address")

# %%
student = {
    "name": "Alice",
    "age":30,
    "address": {
        "city" : "mumbai",
        "pincode": 400001
    }
}

# %%
student
# Out:
# {'name': 'Alice', 'age': 30, 'address': {'city': 'mumbai', 'pincode': 400001}}

# %%
student["address"]["city"]
# Out:
# 'mumbai'

# %%
student["address"]["pincode"]
# Out:
# 400001

# %%
## Adding and modifying items

# Adding new items

person = {"name":"Alice","age":25,}

# %%
person
# Out:
# {'name': 'Alice', 'age': 25}

# %%
person["city"]= "Mumbai"

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Mumbai'}

# %%
person["Phone number"]= "99802877189"

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Mumbai', 'Phone number': '99802877189'}

# %%
# Modify existing items
person['age']
# Out:
# 25

# %%
person['age'] = 35
person
# Out:
# {'name': 'Alice', 'age': 35, 'city': 'Mumbai', 'Phone number': '99802877189'}

# %%
person["city"]= "delhi"
person
# Out:
# {'name': 'Alice', 'age': 35, 'city': 'delhi', 'Phone number': '99802877189'}

# %%
## using update() - add/modify multiple items
person = {"name":"Alice", "age":25,}

# Adding multiple items..

person.update({"city": "Mumbai","phone": 56573654765})

# %%
person.update({"age":45,"name": "Amith"})

# %%
person
# Out:
# {'name': 'Amith', 'age': 45, 'city': 'Mumbai', 'phone': 56573654765}

# %%
## removing items

# method 1 using del keyword
person
# Out:
# {'name': 'Amith', 'age': 45, 'city': 'Mumbai', 'phone': 56573654765}

# %%
del person["age"]

# %%
person
# Out:
# {'name': 'Amith', 'city': 'Mumbai', 'phone': 56573654765}

# %%
del person["phone"]
person
# Out:
# {'name': 'Amith', 'city': 'Mumbai'}

# %%
# using pop(): Return removed values

## Remve and return value
person = {'name':'Amit','age':35,'city': 'Mumbai', 'phone':989856598}

# %%
age = person.pop("age")

# %%
age
# Out:
# 35

# %%
person
# Out:
# {'name': 'Amit', 'city': 'Mumbai', 'phone': 989856598}

# %%
person = {'name': 'Amit', 'age': 35, 'city': 'Mumbai', 'phone': 12948291847}

item = person.popitem()

# %%
type(item)
# Out:
# tuple

# %%
item
# Out:
# ('phone', 12948291847)
