# %% [markdown]
# ##  Tuple
#
# Tuples are immutable (unchangeable), ordered sequences of items. They are defined using parentheses (), with items separated by commas. Like lists, they can contain items of different data types. Because they are immutable, they are often used for fixed collections of items and can be used as keys in dictionaries (whereas lists cannot).
#
# Common Operations and methods:
#
# Tuples support indexing, slicing, len(), and membership testing (in, not in) just like lists. However, they lack methods that modify the tuple (like append, remove, sort, etc.). They have only two primary methods: count() and index().

# %%
## Creation and slicing and indexing

empty_tuple = ()
type(empty_tuple)
# Out:
# tuple

# %%
empty_list = []
type(empty_list)
# Out:
# list

# %%
tech_skills = ("Python", "SQL", "Git", "CI/CD", "Python")
course_info = ("DS101", "Data Science", 15, 4.5)

# %%
tech_skills[-1]
# Out:
# 'Python'

# %%
tech_skills[:3]
# Out:
# ('Python', 'SQL', 'Git')

# %%
# get course name and its rating

name_rating = course_info[1], course_info[-1]
print(name_rating)
print(type(name_rating))
# Out:
# ('Data Science', 4.5)
# <class 'tuple'>

# %%
information = ("Lohit", 35, "banglore", "python")

# %%
name, age, city, skill =information

# %%
name
# Out:
# 'Lohit'

# %%
skill
# Out:
# 'python'

# %%
age
# Out:
# 35

# %%
city
# Out:
# 'banglore'

# %%
city
# Out:
# 'banglore'

# %%
information
# Out:
# ('Lohit', 35, 'banglore', 'python')

# %% [markdown]
# ## tuple.count(item)
# Returns the number of times the specified item appears in the tuple.

# %%
tech_skills = ("Python", "SQL", "Git", "CI/CD", "Python", "SQL", "Python")
ratings = (5, 4, 5, 5, 3, 4, 5)

# %%
tech_skills.count("Python")
# Out:
# 3

# %%
ratings.count(5)
# Out:
# 4

# %%
nested = (1, (2,3), 4, (2,3),4,4,4,4,444)
nested.count(4)
# Out:
# 5

# %%
nested.count(2)
# Out:
# 0

# %% [markdown]
# # tuple.index(item, start, end)
#
# Returns the index of the first occurrence of the specified item. Raises a ValueError if the item is not found. Optional start and end arguments limit the search to a slice.

# %%
tech_skills = ("Python", "SQL", "Git", "CI/CD", "Python", "SQL", "Python")
ratings = (5, 4, 5, 5, 3, 4, 5)

# %%
tech_skills.index("sql".upper())
# Out:
# 1

# %%
tech_skills.index("SQL",2)
# Out:
# 5

# %%
# for 2nd python
tech_skills.index("Python",1)
# Out:
# 4

# %%
# 3rd python index
tech_skills.index("Python", 5)
# Out:
# 6
