# %%
text = "hello"

for ch in (reversed(text)):
    print(ch, end="")
# Out:
# olleh

# %%
text = "hello"

print(text[::-1])
# Out:
# olleh

# %%
text = "hello world"
texts = text.split()
for ch in (texts):
    print(ch[::-1],end=" ")
# Out:
# olleh dlrow

# %%
text = "hello world"

for word in text.split():
    print(word[::-1], end=" ")
# Out:
# olleh dlrow

# %%
text = "hellow world"

result = []

for word in text.split():
    result.append(word[::-1])

print(result)
# Out:
# ['wolleh', 'dlrow']

# %%
text = "hello world"

texts = text.split()
print(texts[::-1])
# Out:
# ['world', 'hello']

# %%
text = "hello world"

texts = text.split()
print(" ".join(texts[::-1]))
# Out:
# world hello

# %%
text = "hello world"

for i in (reversed(text)):
    print(i,end="")
# Out:
# dlrow olleh

# %%
text = "hello world"
print(text[::-1])
# Out:
# dlrow olleh

# %%
text = "hellow world"
print(" ".join(text.split()[::-1]))
# Out:
# world hellow

# %%
text = "hello world"
for word in text.split()[::-1]:
    print(word[::-1], end=" ")
# Out:
# dlrow olleh

# %%
text = "hello world"

count = 0

for ch in text:
    if ch in "aeiou":
        count += 1

print("Vowels:",count)
# Out:
# Vowels: 3

# %%
text = "HELLo WORLD"

count = 0

for ch in text:
    if ch.lower() in "aeiou":
        count += 1
print(count)
# Out:
# 3

# %%
text = "HellO world"

for ch in text:
    if ch.lower() in"aeiou":
        print(ch, end=" ")
# Out:
# e O o

# %%
course = "data science"

count = 0

for ch in course:
    if ch in "aieou":
        count += 1
        print(ch,end=" ")
print()
print(f"Count of vowels are= {count}")
# Out:
# a a i e e
# Count of vowels are= 5

# %%
course = "data science"

count = 0

for ch in course:
    if ch.lower() in "aeiou":
        print(ch,end=" ")
        count += 1

print("\nTotal vowels:",count)
# Out:
# a a i e e
# Total vowels: 5

# %%
string = input("Enter and check your sentence vowels and consonants: ")

vowels = 0
consonants = 0

for ch in string:
    if ch.isalpha():
        if ch.lower() in "aeiou":
            vowels += 1
        else:
            consonants += 1

print("Vowels: ",vowels)
print("Consonants: ",consonants)
# Out:
# Vowels:  5
# Consonants:  6

# %%
string = input("Enter the text: ")

vowels = 0
consonants = 0
digits = 0

for ch in string:
    if ch.isalpha():
        if ch.lower() in "aeiou":
            vowels += 1
        else:
            consonants += 1
    elif ch.isdigit():
        digits += 1

print("Vowels:",vowels)
print("Consonants:",consonants)
print("digits: ",digits)
# Out:
# Vowels: 4
# Consonants: 4
# digits:  3

# %%
string = input("Enter the sentence: ")

print("My string is:", string)

vowels = 0
consonants = 0
digits = 0
spaces = 0

for ch in string:
    if ch.isalpha():
        if ch.lower() in "aeiou":
            vowels += 1
        else:
            consonants += 1
    elif ch.isdigit():
        digits += 1
    elif ch == " ":
        spaces += 1

print("Vowels",vowels)
print("Consonants", consonants)
print("digits", digits)
print("Spaces",spaces)
# Out:
# My string is: I am groot, my age is 28
# Vowels 7
# Consonants 8
# digits 2
# Spaces 6

# %%
string = input("Enter the string: ")

vowels = 0
consonants = 0
digits = 0
spaces = 0
special = 0

for ch in string:
    if ch.isalpha():
        if ch.lower() in "aeiou":
            vowels += 1
        else:
            consonants += 1
    elif ch.isdigit():
        digits += 1
    elif ch.isspace():
        spaces += 1
    else:
        special +=1

print("Vowels: ",vowels)
print("Consonants: ",consonants)
print("Digits: ",digits)
print("Spaces: ",spaces)
print("Special: ",special)
# Out:
# Vowels:  4
# Consonants:  6
# Digits:  2
# Spaces:  5
# Special:  3

# %%
password = input("Enter Password: ")

letters = 0
digits = 0
special = 0

for ch in password:
    if ch.isalpha():
        letters += 1
    elif ch.isdigit():
        digits += 1
    else:
        special += 1
    
if letters > 0 and digits > 0 and special > 0:
    print("Password is strong")
elif letters > 0 and digits > 0:
    print("Password is medium")
else:
    print("Password is Weak")

print("Letters: ",letters)
print("Digits: ",digits)
print("Specials: ",special)
# Out:
# Password is medium
# Letters:  9
# Digits:  1
# Specials:  0
