# %% [markdown]
# ##str.splt(sep=None, maxsplit=-1)
#
# Explanation: Return a list of substring (words) by splitting the at occurrence of the separator sep.
#
# *If sep is omitted or None, splits by any whitespace character and discards empty strings.
#
# *If sep is specified, splits exactly at that separator.
#
# *maxsplit: If specified, performs at most maxsplit splits (resulting in maxsplit + 1 elements in the list). The remainder of the string is the last element.

# %%
course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps, Python,SQL,Git"
institute = "Edukron"

# %%
words = course_slogan.split()

# %%
len(words)
# Out:
# 6

# %%
type(words)
# Out:
# list

# %%
type(course_slogan)
# Out:
# str

# %%
words
# Out:
# ['Learn', 'Data', 'Engineering', 'with', 'Real-Time', 'Projects']

# %%
tech_stack = "Azure DevOps, Python,SQL,Git"
Skills = tech_stack.split(",")

# %%
Skills
# Out:
# ['Azure DevOps', ' Python', 'SQL', 'Git']

# %%
type(Skills)
# Out:
# list

# %%
len(Skills)
# Out:
# 4

# %%
# spltting institute name by char "k"

institute = "Edukron"
institute.split("k")
# Out:
# ['Edu', 'ron']

# %%
splitted = course_slogan.split(maxsplit=3)
splitted
# Out:
# ['Learn', 'Data', 'Engineering', 'with Real-Time Projects']

# %%
again_split = course_slogan.split(maxsplit=1)
again_split
# Out:
# ['Learn', 'Data Engineering with Real-Time Projects']

# %%
len(splitted)
# Out:
# 4

# %%
multi_space = "Azure.   DevOps  Python"
multi_space.split()
# Out:
# ['Azure.', 'DevOps', 'Python']

# %%
lst = ['Azure.', 'DevOps', 'Python']

# %%
lst[0] = "sql"

# %%
lst
# Out:
# ['sql', 'DevOps', 'Python']

# %%
lst[1] = "whatever"

# %%
lst
# Out:
# ['sql', 'whatever', 'Python']

# %% [markdown]
# str.join(iterable) passing list of strings..
#
# The opposite of split.. Takes an itarable(list or tuple)

# %%
course_list = ["Date Science", "Data Engineering", "Azure DevOps"]
tech_skills = ("Python", "SQL", "Git", "CI/CD")
words = ['Learn', 'Data', 'Engineering']

# %%
joined_courses = ",".join(course_list)
print(f"1. Joined courses: {joined_courses}")
# Out:
# 1. Joined courses: Date Science,Data Engineering,Azure DevOps

# %%
joined_skills = "-".join(tech_skills)
print(f"2. Joined skills: {joined_skills}")
# Out:
# 2. Joined skills: Python-SQL-Git-CI/CD

# %%
sentence = " ".join(words)
print(f"Joined sentence: {sentence}")
# Out:
# Joined sentence: Learn Data Engineering
