# %%
a=15
b=4
print(a+b)
# Out:
# 19

# %%
print(a-b)
# Out:
# 11

# %%
a*b
# Out:
# 60

# %%
a+b
a-b
a*b
a/b
a//b
a%b
a**b
# Out:
# 50625

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
x=10
y=20
print(x%y)
# Out:
# 10

# %%
e=10
f=7
print(e%f)
# Out:
# 3

# %%
x=10
y=20

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
print(x)
print(y)
# Out:
# 10
# 20

# %%
print(x==y)
# Out:
# False

# %%
print(x!=y)
# Out:
# True

# %%
print(x>y)
# Out:
# False

# %%
print(x>=y)
# Out:
# False

# %%
print(x<y)
# Out:
# True

# %%
x=50

# %%
x=x+10

# %%
x
# Out:
# 60

# %%
x+=10
x
# Out:
# 70

# %%
x-=30
x
# Out:
# -20

# %%
x*=30
x
# Out:
# -600

# %%
x+=650

# %%
x
# Out:
# 50

# %%
x//=2

# %%
x
# Out:
# 25

# %%
x//=2
x
# Out:
# 12

# %%
x%=10
x
# Out:
# 2

# %%
x**=3
x
# Out:
# 8

# %%
x=10
x
# Out:
# 10

# %%
age = 25
has_id = True

# %%
print(age >=18 and has_id)
# Out:
# True

# %%
display = input("What is your name? ")
print("Hello", display)
blood_group = input("What is your blood group? ")
print("Your blood group is", blood_group)
age = input("Enter your age: ")
print("You are", age, "years old.")
# Out:
# Hello Panchakshari
# Your blood group is A+
# You are 27 years old.

# %%
x = [1,2,3]
y = x
z = [1,2,3]

# %%
x
# Out:
# [1, 2, 3]

# %%
y
# Out:
# [1, 2, 3]

# %%
z
# Out:
# [1, 2, 3]

# %%
x = [1,2,3]
y = x
z = [1,2,3]

print(x is y)
print(x is z)
print(x == z)
print(x is not z)
print(x is not y)
# Out:
# True
# False
# True
# True
# False

# %%
fruits = ["apple", "blueberry", "Mango"]

# %%
print("blueberry" in fruits)
print("Mango" in fruits)
print("ananas" in fruits)
print("apple" not in fruits)
print("apple" in fruits)
# Out:
# True
# True
# False
# False
# True

# %%
numbers = [1,2,3,4,5]
print(10 in numbers)
# Out:
# False

# %%
print(4 in numbers)
# Out:
# True
