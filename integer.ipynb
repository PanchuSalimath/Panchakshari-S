# %%
new_students_batch1 = 120
total_students = 1500
total_students = total_students + new_students_batch1
print(f"1. Total students after batch 1: {total_students}")
# Out:
# 1. Total students after batch 1: 1620

# %%
ds_modules = 15
de_modules = 18
total_modules = ds_modules + de_modules
print(f"2. Total modules in DS & DE: {total_modules}")
# Out:
# 2. Total modules in DS & DE: 33

# %%
batch_size_1 = 50
batch_size_2 = 45
combined_batch_size = batch_size_1 + batch_size_2
print(f"Combined size of the batches: {combined_batch_size}")
# Out:
# Combined size of the batches: 95

# %%
# 4. Adding zero doesn't change the value
initial_count = 100
final_count = initial_count + 0
print(f"Count after adding 0: {final_count}")
# Out:
# Count after adding 0: 100

# %%
# 5. Adding a negative number (subtraction)
active_students = 1620
dropouts = -20
active_students = active_students + dropouts
print(f"Active students after dropouts: {active_students}")
# Out:
# Active students after dropouts: 1600

# %%
# 6. Incrementing a counter
completed_projects = 5
completed_projects = completed_projects + 1
print(f"7. Completed projects after increment: {completed_projects}")
# Out:
# 7. Completed projects after increment: 6

# %%
# 7. Summing course durations (in weeks)
duration1 = 8
duration2 = 12
total_duration = duration1 + duration2
print(f"7. Total duration in weeks: {total_duration}")
# Out:
# 7. Total duration in weeks: 20

# %%
#Combining positive and negative changes
student_change = 50 + (-10) + 30
print(f"Net Students change: {student_change}")
# Out:
# Net Students change: 70

# %%
revenue = 50000
revenue_after_discount = revenue - 0
print(f" Revenue after 0% discount: {revenue_after_discount}")
# Out:
#  Revenue after 0% discount: 50000

# %%
costs = 60000
profit = revenue - costs
print(f"5. Profit (can be negative): {profit}")
# Out:
# 5. Profit (can be negative): -10000

# %%
current_year = 2024
launch_year = 2020
years_active = current_year - launch_year
print(f"7. Edukron years active: {years_active}")
# Out:
# 7. Edukron years active: 4
